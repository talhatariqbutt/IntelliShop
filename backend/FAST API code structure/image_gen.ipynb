# %%
import os 
os.environ['HF_TOKEN']='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'

# %%
from gradio_client import Client
from PIL import Image as PILImage
from IPython.display import display

# Initialize the client with the model you're using
client = Client("black-forest-labs/FLUX.1-schnell")
# Out:
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔

# %%
# Generate the image with the specified prompt
result = client.predict(
    prompt = "black and white striped dress shirt full view of only shirt",
    seed = 0,
    randomize_seed = True,
    width=1024,
    height=1024,
    num_inference_steps=4,
    api_name="/infer"
)

# Print the result to inspect it
print(result)

# The result is a tuple, where the first element is the local file path
image_path = result[0]  # Adjust this if `result` is in a different format

# Open and display the image using PIL
img = PILImage.open(image_path)
display(img)
# Out:
# ('C:\\Users\\qasim\\AppData\\Local\\Temp\\gradio\\cc4b9bdf8a3ff1a6184ad49cf24c40b6ec7be089031ad68e1f7e4960f0f8aecc\\image.webp', 1005850287)
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>
